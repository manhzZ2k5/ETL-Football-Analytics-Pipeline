# %%
from pathlib import Path
import soccerdata as sd
import pandas as pd
# Out:
# [11/15/25 21:41:18] INFO     No custom team name replacements found. You can configure these in       ]8;id=486487;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=122258;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\Admin\soccerdata\config\teamname_replacements.json.
# ...

# %%
fbref = sd.FBref(leagues="ENG-Premier League",seasons=['2021','2122','2223','2324','2425'])
# Out:
# [11/15/25 15:50:47] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\FBref              ]8;id=717657;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=388146;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\
#                     WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\_common.py:145: UserWarning: Season id "2021" is ambiguous:
#                              interpreting as "20-21"
#                                warnings.warn(msg, stacklevel=1)

# %%
team_season = fbref.read_player_season_stats()
team_season.head(5)
# Out:
# [11/15/25 15:51:28] WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)
#                                                          nation    pos age  \
#
# league             season team    player
# ENG-Premier League 2021   Arsenal Ainsley Maitland-Niles    ENG  MF,DF  22
# ...

# %%
# season_team_df = pd.DataFrame(season_team)
# season_team_df.head(5)
# season_team_df.to_csv("")
# Out:
#                                       players_used   Age  Poss Playing Time  \
#                                                                          MP
# league             season team
# ENG-Premier League 2021   Arsenal               29  25.9  53.5           38
#                           Aston Villa           24  25.2  48.5           38
#                           Brighton              27  25.8  51.1           38
#                           Burnley               25  28.3  42.1           38
#                           Chelsea               27  26.0  60.9           38
#
#                                                        Performance          \
#                                       Starts   Min 90s         Gls Ast G+A
# league             season team
# ENG-Premier League 2021   Arsenal        418  3420  38          53  38  91
#                           Aston Villa    418  3420  38          52  38  90
# ...

# %%
player_season = fbref.read_player_season_stats()
player_season_df = pd.DataFrame(player_season)


out_path = Path("../data/fbref_fact_player_season_stats.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)  
player_season_df.to_csv(out_path, index=False, encoding="utf-8")

player_season_df.to_csv("../data/fbref_fact_player_season_stats.csv")
# Out:
# [11/11/25 01:28:50] WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)

# %%
player_match = fbref.read_player_match_stats()
player_match_df = pd.DataFrame(player_match)


out_path = Path("../data/fbref_fact_player_match_stats.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)  
player_match_df.to_csv(out_path, index=False, encoding="utf-8")

player_match_df.to_csv("../data/fbref_fact_player_match_stats.csv")

# %%
team_match = fbref.read_team_match_stats()
team_match_df = pd.DataFrame(team_match)


out_path = Path("../data/fbref_fact_team_match.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)  
team_match_df.to_csv(out_path, index=False, encoding="utf-8")

team_match_df.to_csv("../data/fbref_fact_team_match.csv")
# Out:
# [11/11/25 09:54:23] WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)

# %%
team_season = fbref.read_team_season_stats()
team_season_df = pd.DataFrame(team_season)

out_path = Path("../data/fbref_fact_team_season.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)  
team_match_df.to_csv(out_path, index=False, encoding="utf-8")

team_season_df.to_csv("../data/fbref_fact_team_season.csv")
# Out:
# [11/11/25 11:58:40] WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)

# %%
# fotmob = sd.FotMob(leagues="ENG-Premier League",seasons=['2425'])
# Out:
# [11/11/25 12:58:40] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\FotMob             ]8;id=477828;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=729751;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
# schedule = fotmob.read_schedule()
# schedule.head(5)
# Out:
#                                                                       round  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Manchester United-Fulham             1
#                           2024-08-17 Arsenal-Wolverhampton Wanderers      1
#                           2024-08-17 Everton-Brighton & Hove Albion       1
#                           2024-08-17 Ipswich Town-Liverpool               1
#                           2024-08-17 Newcastle United-Southampton         1
#
#                                                                      week  \
# league             season game
# ENG-Premier League 2425   2024-08-16 Manchester United-Fulham           1
#                           2024-08-17 Arsenal-Wolverhampton Wanderers    1
#                           2024-08-17 Everton-Brighton & Hove Albion     1
#                           2024-08-17 Ipswich Town-Liverpool             1
#                           2024-08-17 Newcastle United-Southampton       1
#
# ...

# %%
understat = sd.Understat(leagues="ENG-Premier League",seasons=['2021','2122','2223','2324','2425'])
shot = understat.read_shot_events()

shot_df = pd.DataFrame(shot)

out_path = Path("../data/understat_fact_shot.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)  
shot_df.to_csv(out_path, index=False, encoding="utf-8")

shot_df.to_csv("../data/understat_fact_shot.csv")
# Out:
# [11/15/25 13:10:15] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\Understat          ]8;id=945344;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=192873;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\
#                     WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\_common.py:145: UserWarning: Season id "2021" is ambiguous:
#                              interpreting as "20-21"
#                                warnings.warn(msg, stacklevel=1)

# %%
understat = sd.Understat(leagues="ENG-Premier League",seasons=['2425'])
player = understat.read_player_season_stats()
df = pd.DataFrame(player)
df.to_csv(r'D:\ETL_Football\data_processed\test_player_season_clean1.csv', index=False)
# Out:
# [11/15/25 21:57:39] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\Understat          ]8;id=568179;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=446760;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
# sofifa = sd.SoFIFA(leagues="ENG-Premier League",versions='latest')
# team = sofifa.read_player_ratings()
# team.head(10)

# %%
# team.head(10)
# Out:
#                    fifa_edition       update overallrating potential crossing  \
# player
# Louis Jordan Beyer        FC 26  Nov 5, 2025            74        78       61
#
#                    finishing headingaccuracy shortpassing volleys dribbling  \
# player
# Louis Jordan Beyer        29              73           73      31        68
#
#                     ... penalties composure defensiveawareness standingtackle  \
# player              ...
# Louis Jordan Beyer  ...        42        74                 74             75
#
#                    slidingtackle gk_diving gk_handling gk_kicking  \
# player
# Louis Jordan Beyer            74         7           7         13
#
#                    gk_positioning gk_reflexes
# player
# Louis Jordan Beyer             11          11
#
# [1 rows x 38 columns]

# %%
# season = fbref.read_seasons()
# season.head(5)
# Out:
# [11/11/25 14:25:35] WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
#                              version, this will no longer exclude empty or all-NA columns when
#                              determining the result dtypes. To retain the old behavior, exclude the
#                              relevant entries before the concat operation.
#                                pd.concat(dfs)
#                                 format  \
# league             season
# ENG-Premier League 2021    round-robin
#                    2122    round-robin
#                    2223    round-robin
#                    2324    round-robin
# ...

# %%
# matchhistory = sd.MatchHistory(leagues="ENG-Premier League",seasons=['2425'])
# Out:
# [11/11/25 14:27:04] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\MatchHistory       ]8;id=516452;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=654775;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
# fotmob = sd.FotMob(leagues="ENG-Premier League",seasons=['2425'])
# f = fotmob.read_team_match_stats()
# f
